# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamelzawawyyy/neural-machine-translation/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
path = "/content/drive/MyDrive/nmt-seq2seq+attention"
sys.path.append(path)
os.chdir(path)

# !pwd
# !ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/nmt-seq2seq+attention
#  data_preprocessing.py	'inference .py'   model_seq2seq.py   training.py

# %%
# !python data_preprocessing.py
# Out:
# ⏳ Loading Opus100 dataset...
# README.md: 65.4kB [00:00, 109MB/s]
# ...
# ar-en/test-00000-of-00001.parquet: 100% 214k/214k [00:01<00:00, 164kB/s]
# ar-en/train-00000-of-00001.parquet: 100% 99.3M/99.3M [00:01<00:00, 54.6MB/s]
# ar-en/validation-00000-of-00001.parquet: 100% 979k/979k [00:00<00:00, 1.21MB/s]
# Generating test split: 100% 2000/2000 [00:00<00:00, 61309.48 examples/s]
# Generating train split: 100% 1000000/1000000 [00:01<00:00, 799771.03 examples/s]
# Generating validation split: 100% 2000/2000 [00:00<00:00, 120416.98 examples/s]
# 🎓 Training Tokenizer...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/opus_nmt_data/tokenizer_input.txt
#   input_format:
#   model_prefix: /content/opus_nmt_data/spm
#   model_type: UNIGRAM
#   vocab_size: 9000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
# ...

# %%
# !python model_seq2seq.py

# %%
# !python training.py
# Out:
# ⏳ Loading Opus100 dataset...
# ...
# 🎓 Training Tokenizer...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/opus_nmt_data/tokenizer_input.txt
#   input_format:
#   model_prefix: /content/opus_nmt_data/spm
#   model_type: UNIGRAM
#   vocab_size: 9000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 1
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
# ...

# %%
# !python 'inference .py'
# Out:
# ⏳ Loading Opus100 dataset...
# ...
# 🎓 Training Tokenizer...
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: /content/opus_nmt_data/tokenizer_input.txt
#   input_format:
#   model_prefix: /content/opus_nmt_data/spm
#   model_type: UNIGRAM
#   vocab_size: 9000
#   self_test_sample_size: 0
#   character_coverage: 0.9995
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 1
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 3
# ...
